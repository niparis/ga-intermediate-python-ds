# %% [markdown]
# # Youtube
#
# Download data from
# https://www.kaggle.com/datasnaek/youtube-new
#
# And copy it in the `datasets` folder.
#
# Don't unzip

# %%
    
import zipfile
import pandas as pd
import io
import json

countries = {}
categories = {}

with zipfile.ZipFile("datasets/youtube-new.zip") as z:
    for file in z.filelist:
        print(f'processing {file.filename}')
        key = file.filename.split('.')[0]        
        if file.filename.endswith('.csv'):
            with z.open(file.filename) as f:
                countries[key] = pd.read_csv(io.StringIO(f.read().decode('latin-1')))
        if file.filename.endswith('.json'):                
            with z.open(file.filename) as f:
                categories[key] = json.loads(f.read())

# %% [markdown]
# ## Let's have a look at our data

# %%
df = countries['CAvideos']
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40881.000000  4.088100e+04  4.088100e+04  4.088100e+04   4.088100e+04
# mean      20.795553  1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# std        6.775054  3.390913e+06  1.326895e+05  1.900837e+04   2.157902e+04
# min        1.000000  7.330000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       20.000000  1.439020e+05  2.191000e+03  9.900000e+01   4.170000e+02
# 50%       24.000000  3.712040e+05  8.780000e+03  3.030000e+02   1.301000e+03
# 75%       24.000000  9.633020e+05  2.871700e+04  9.500000e+02   3.713000e+03
# max       43.000000  1.378431e+08  5.053338e+06  1.602383e+06   1.114800e+06

# %%
print('Unique values for each column')
df.nunique()
# Out:
# Unique values for each column
# video_id                  24427
# trending_date               205
# title                     24573
# channel_title              5076
# category_id                  17
# publish_time              23613
# tags                      20157
# views                     40170
# likes                     24676
# dislikes                   6241
# comment_count             11172
# thumbnail_link            24422
# comments_disabled             2
# ratings_disabled              2
# video_error_or_removed        2
# description               22345
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40881 entries, 0 to 40880
# Data columns (total 16 columns):
# video_id                  40881 non-null object
# trending_date             40881 non-null object
# title                     40881 non-null object
# channel_title             40881 non-null object
# category_id               40881 non-null int64
# publish_time              40881 non-null object
# tags                      40881 non-null object
# views                     40881 non-null int64
# likes                     40881 non-null int64
# dislikes                  40881 non-null int64
# comment_count             40881 non-null int64
# thumbnail_link            40881 non-null object
# comments_disabled         40881 non-null bool
# ratings_disabled          40881 non-null bool
# video_error_or_removed    40881 non-null bool
# description               39585 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %% [markdown]
# ## Objectives
# 1. What are the top 10 tags for each channel ?
# 2. What are the top 25 tags in one country ?
# 3. Fix the bugs !
# 4. Multiprocessing - What are the top 25 tags in EACH country ?
# 4. For each of the top 25 tags (worldwide), calculate the ratios: like, dislike & comments (by view)

# %% [markdown]
# ## 1. What are the top 10 tags for each channel ?
#
# A nice use case for a custom group by
#
# Custom group by may seem a bit complicated at first, but they give a lot of flexibility - this way you don't have to learn the whole pandas library !
#
# We're going to create a custom group by *step by step*, so that you can understand the thought process you have to go through.

# %%
# we have to build a custom group by
# let's creae a group by object containing the data of a single entity
# we'll get quick calculations this way

# a group by object performs no calculations in itself

gb = df.loc[df['channel_title'] == '20th Century Fox'].groupby('channel_title')['tags']

# %%
# working on a single, but large group lets us experiment quickly while covering most edge cases

# we create a very basic custom function that we use to observe the data we receive from the groupby aggregation
# let's get the inner variable to experiment with it

def foo(x):
    print('start')
    print(x)
    print(type(x))
    print('end')   
    return []

gb.agg(foo)
# Out:
# start
# 291      Trailer|"Hugh Jackman"|"Michelle Williams"|"Za...
# 400      Trailer|"Deadpool"|"20th Century Fox (Producti...
# 600      Trailer|"Deadpool"|"20th Century Fox (Producti...
# 800      Trailer|"Deadpool"|"20th Century Fox (Producti...
# 1001     Trailer|"Deadpool"|"20th Century Fox (Producti...
# 1210     Trailer|"Deadpool"|"20th Century Fox (Producti...
# 1499     Trailer|"Deadpool"|"20th Century Fox (Producti...
# 3073     Trailer|"Nick Robinson"|"Katherine Langford"|"...
# 3234     Trailer|"Nick Robinson"|"Katherine Langford"|"...
# 3454     Trailer|"Nick Robinson"|"Katherine Langford"|"...
# 3792     Trailer|"Nick Robinson"|"Katherine Langford"|"...
# 5018     Trailer|"alita"|"battle angel"|"alita: battle ...
# 5203     Trailer|"alita"|"battle angel"|"alita: battle ...
# 5409     Trailer|"alita"|"battle angel"|"alita: battle ...
# 5641     Trailer|"alita"|"battle angel"|"alita: battle ...
# 5932     Trailer|"alita"|"battle angel"|"alita: battle ...
# 11208    Trailer|"Jennifer Lawrence"|"Joel Edgerton"|"M...
# 11432    Trailer|"Jennifer Lawrence"|"Joel Edgerton"|"M...
# 11785    Trailer|"Jennifer Lawrence"|"Joel Edgerton"|"M...
# 12453    Trailer|"Nick Robinson"|"Katherine Langford"|"...
# 12646    Trailer|"Nick Robinson"|"Katherine Langford"|"...
# 12946    Trailer|"Nick Robinson"|"Katherine Langford"|"...
# 16759    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 16961    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 17166    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 17387    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 17643    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 17840    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 25322    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 25522    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 25722    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 25924    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 26130    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 26431    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 26692    Trailer|"the darkest minds"|"darkest minds"|"n...
# 29922    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 30131    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 30366    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 30680    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 33978    Trailer|"The Predator"|"Boyd Holbrook"|"Trevan...
# 34120    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 34327    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 34821    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 35415    Trailer|"Deadpool"|"20th Century Fox (Producti...
# 38947    Trailer|"Viola Davis"|"Michelle Rodriguez"|"El...
# 39223    Trailer|"Viola Davis"|"Michelle Rodriguez"|"El...
# 39657    Trailer|"Jeff Bridges"|"Cynthia Erivo"|"Dakota...
# Name: tags, dtype: object
# <class 'pandas.core.series.Series'>
# end
# channel_title
# 20th Century Fox    []
# Name: tags, dtype: object

# %%
# we start working on the logox
# first we notice that the tags are separated by pipes ('|')
# let's split each of the string by the pipe character
# the "x" object will now containt a list of strings in each row 

def foo(x):
    print('start')
    # split by '|'
    res = x.apply(lambda x: x.split('|'))
    print(res)    
    return 'v'

gb.agg(foo)
# Out:
# start
# 291      [Trailer, "Hugh Jackman", "Michelle Williams",...
# 400      [Trailer, "Deadpool", "20th Century Fox (Produ...
# 600      [Trailer, "Deadpool", "20th Century Fox (Produ...
# 800      [Trailer, "Deadpool", "20th Century Fox (Produ...
# 1001     [Trailer, "Deadpool", "20th Century Fox (Produ...
# 1210     [Trailer, "Deadpool", "20th Century Fox (Produ...
# 1499     [Trailer, "Deadpool", "20th Century Fox (Produ...
# 3073     [Trailer, "Nick Robinson", "Katherine Langford...
# 3234     [Trailer, "Nick Robinson", "Katherine Langford...
# 3454     [Trailer, "Nick Robinson", "Katherine Langford...
# 3792     [Trailer, "Nick Robinson", "Katherine Langford...
# 5018     [Trailer, "alita", "battle angel", "alita: bat...
# 5203     [Trailer, "alita", "battle angel", "alita: bat...
# 5409     [Trailer, "alita", "battle angel", "alita: bat...
# 5641     [Trailer, "alita", "battle angel", "alita: bat...
# 5932     [Trailer, "alita", "battle angel", "alita: bat...
# 11208    [Trailer, "Jennifer Lawrence", "Joel Edgerton"...
# 11432    [Trailer, "Jennifer Lawrence", "Joel Edgerton"...
# 11785    [Trailer, "Jennifer Lawrence", "Joel Edgerton"...
# 12453    [Trailer, "Nick Robinson", "Katherine Langford...
# 12646    [Trailer, "Nick Robinson", "Katherine Langford...
# 12946    [Trailer, "Nick Robinson", "Katherine Langford...
# 16759    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 16961    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 17166    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 17387    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 17643    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 17840    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 25322    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 25522    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 25722    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 25924    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 26130    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 26431    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 26692    [Trailer, "the darkest minds", "darkest minds"...
# 29922    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 30131    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 30366    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 30680    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 33978    [Trailer, "The Predator", "Boyd Holbrook", "Tr...
# 34120    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 34327    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 34821    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 35415    [Trailer, "Deadpool", "20th Century Fox (Produ...
# 38947    [Trailer, "Viola Davis", "Michelle Rodriguez",...
# 39223    [Trailer, "Viola Davis", "Michelle Rodriguez",...
# 39657    [Trailer, "Jeff Bridges", "Cynthia Erivo", "Da...
# Name: tags, dtype: object
# channel_title
# 20th Century Fox    v
# Name: tags, dtype: object

# %%
# next we want to combine our lists of strings in a single list
# we use a simple nested loop for this

def foo(x):
    print('start')
    # split by '|'
    res = x.apply(lambda x: x.split('|'))
    
    # flatten in single list
    flat = []
    for row in res:
        for elem in row:
            flat.append(elem.strip('"')) # removes the aesthetically unpleasant "
    print(flat)
    
    # return a set (so it keeps only unique elements)
    return tuple(set(flat))

gb.agg(foo)
# Out:
# start
# ['Trailer', 'Hugh Jackman', 'Michelle Williams', 'Zac Efron', 'Zendaya', 'Rebecca Ferguson', 'pasek and paul', 'la la land', 'moulin rouge', 'high school musical', 'hugh jackman musical', 'zac efron musical', 'musical', 'the greatest showman', 'greatest showman', 'Michael Gracey', 'P.T. Barnum', 'Barnum and Bailey', 'Barnum Circus', 'Barnum and Bailey Circus', '20th century fox', 'greatest showman trailer', 'trailer', 'official trailer', 'the greatest showman trailer', 'logan', 'Benj Pasek', 'Justin Paul', 'Trailer', 'Deadpool', '20th Century Fox (Production Company)', 'Deadpool Movie', 'Ryan Reynolds (Celebrity)', 'Ed Skrein (Musical Artist)', 'T. J. Miller (TV Writer)', 'Gina Carano (Martial Artist)', 'Red band', 'Red band deadpool', 'Marvel', 'Marvel Comics', 'Comic Book (Comic Book Genre)', 'Dead pool', 'Deadpool green band', 'Deadpool red band', 'Action', 'Comedy', 'Action Comedy', 'X-Men (Award-Winning Work)', 'Trailer', 'Deadpool', '20th Century Fox (Production Company)', 'Deadpool Movie', 'Ryan Reynolds (Celebrity)', 'Ed Skrein (Musical Artist)', 'T. J. Miller (TV Writer)', 'Gina Carano (Martial Artist)', 'Red band', 'Red band deadpool', 'Marvel', 'Marvel Comics', 'Comic Book (Comic Book Genre)', 'Dead pool', 'Deadpool green band', 'Deadpool red band', 'Action', 'Comedy', 'Action Comedy', 'X-Men (Award-Winning Work)', 'Trailer', 'Deadpool', '20th Century Fox (Production Company)', 'Deadpool Movie', 'Ryan Reynolds (Celebrity)', 'Ed Skrein (Musical Artist)', 'T. J. Miller (TV Writer)', 'Gina Carano (Martial Artist)', 'Red band', 'Red band deadpool', 'Marvel', 'Marvel Comics', 'Comic Book (Comic Book Genre)', 'Dead pool', 'Deadpool green band', 'Deadpool red band', 'Action', 'Comedy', 'Action Comedy', 'X-Men (Award-Winning Work)', 'Trailer', 'Deadpool', '20th Century Fox (Production Company)', 'Deadpool Movie', 'Ryan Reynolds (Celebrity)', 'Ed Skrein (Musical Artist)', 'T. J. Miller (TV Writer)', 'Gina Carano (Martial Artist)', 'Red band', 'Red band deadpool', 'Marvel', 'Marvel Comics', 'Comic Book (Comic Book Genre)', 'Dead pool', 'Deadpool green band', 'Deadpool red band', 'Action', 'Comedy', 'Action Comedy', 'X-Men (Award-Winning Work)', 'Trailer', 'Deadpool', '20th Century Fox (Production Company)', 'Deadpool Movie', 'Ryan Reynolds (Celebrity)', 'Ed Skrein (Musical Artist)', 'T. J. Miller (TV Writer)', 'Gina Carano (Martial Artist)', 'Red band', 'Red band deadpool', 'Marvel', 'Marvel Comics', 'Comic Book (Comic Book Genre)', 'Dead pool', 'Deadpool green band', 'Deadpool red band', 'Action', 'Comedy', 'Action Comedy', 'X-Men (Award-Winning Work)', 'Trailer', 'Deadpool', '20th Century Fox (Production Company)', 'Deadpool Movie', 'Ryan Reynolds (Celebrity)', 'Ed Skrein (Musical Artist)', 'T. J. Miller (TV Writer)', 'Gina Carano (Martial Artist)', 'Red band', 'Red band deadpool', 'Marvel', 'Marvel Comics', 'Comic Book (Comic Book Genre)', 'Dead pool', 'Deadpool green band', 'Deadpool red band', 'Action', 'Comedy', 'Action Comedy', 'X-Men (Award-Winning Work)', 'Trailer', 'Nick Robinson', 'Katherine Langford', 'Alexandra Shipp', 'Jorge Lendeborg', 'Miles Heizer', 'Keiynan Lonsdale', 'Logan Miller', 'Jennifer Garner', 'Josh Duhamel', 'Tony Hale', 'Greg Berlanti', 'Wyck Godfrey', 'Marty Bowen', 'Dawsonâ\x80\x99s Creek', 'Brothers & Sisters', 'Becky Albertalli', 'Simon vs. the Homo Sapiens Agenda', 'LoveSimon', '20th Century FOX', 'gay', 'coming out', 'coming out story', 'gay coming out story', 'Trailer', 'Nick Robinson', 'Katherine Langford', 'Alexandra Shipp', 'Jorge Lendeborg', 'Miles Heizer', 'Keiynan Lonsdale', 'Logan Miller', 'Jennifer Garner', 'Josh Duhamel', 'Tony Hale', 'Greg Berlanti', 'Wyck Godfrey', 'Marty Bowen', 'Dawsonâ\x80\x99s Creek', 'Brothers & Sisters', 'Becky Albertalli', 'Simon vs. the Homo Sapiens Agenda', 'LoveSimon', '20th Century FOX', 'gay', 'coming out', 'coming out story', 'gay coming out story', 'Trailer', 'Nick Robinson', 'Katherine Langford', 'Alexandra Shipp', 'Jorge Lendeborg', 'Miles Heizer' ...
# channel_title
# 20th Century Fox    (hunger games, Carrie Coon, Jason Matthews, Si...
# Name: tags, dtype: object

# %%
# let's give a proper name to our function and apply it to the whole dataset
# and remove all the print statements !! else it will freeze our notebook
# The nested loop can be simplified to a list comp

# now we have all unique tags per channel - nice, but not what we need
gb_all = df.groupby('channel_title')[['tags']]

def unique_tags(x):
    # split by '|'
    res = x.apply(lambda x: x.split('|')) 
    # flatten in single list
    flat = [elem.strip('"') for row in res for elem in row]
    # return a set (so it keeps only unique elements)
    return tuple(set(flat))

(gb_all.agg([unique_tags, 'count'])
       .droplevel(level=0, axis='columns')
       .sort_values(by='count', ascending=False)
)
# Out:
#                                                                                           unique_tags  \
# channel_title
# VikatanTV                                           (deiva magal serial 01.12.17, priyamanaval 101...
# etvteluguindia                                      (comedy skits in telugu, latest telugu serials...
# Flowers Comedy                                      (moosa, Juhi Rustagi, college campus comedy, p...
# ETV Plus India                                      (comedy skits in telugu, chalaki chanti, Mahes...
# SAB TV                                              (jetha babita, canada visit, break door, top e...
# RadaanMedia                                         (Radhika in funny character, vellai thamarai, ...
# mallemalatv                                         (, Auto Punches, sekhar master, Sudheer, Rajiv...
# SET India                                           (game show, the kapil sharma show clips, docto...
# ETV Jabardasth                                      (comedy skits in telugu, chalaki chanti, raisi...
# Vijay Television                                    (Promo, hasan, balaji, Entertainment King, Tal...
# Tarang TV                                           (odia serial, odia tarang tv serial, nua bohu ...
# T-Series                                            (t series mixtape, Veerey Ki Wedding movie son...
# Mazhavil Manorama                                   (, Udan Panam l EPI 91, mahiyile adaar payyan....
# Technical Guruji                                    (one plus, OnePlus 6 India, Smallest Phone, lg...
# Study IQ education                                  (padmavati, June current affairs 2018, indian ...
# V6 News Telugu                                      (Bithiri Sathi New Business, hyderabad mmts, B...
# zeetv                                               (Promo, kumkum bhagya latest episode, kumkum b...
# Speed Records                                       (Black N White new video, muzical dr songs, Ki...
# SunTV Tamil                                         (Azhagu Tamil Serial, Azhagu, Sun Nxt, Sun TV ...
# zeetvtelugu                                         (Telugu Tv Serials, zeetvtelugu serials, ozee,...
# Black Sheep                                         (first day of college, military, thaaiveedu, c...
# zeemarathi                                          (Tuzhat Jeev Rangala, mazya navryachi bayko, o...
# Colors TV                                           (Harshad Chopra, bepanah bepanah, hindi shows,...
# FilterCopy                                          (father, non-vegetarian, final year, Qarib Qar...
# Sony PAL                                            (watch cid for free, daya's mom, drama, Famous...
# Saregama TVShows                                    (valli 17th May serial, chandra epi 993, chand...
# Aditya Music                                        (Hello Telugu Songs, KalyanRam, Guruvaram Vide...
# T-Series Apna Punjab                                (masha ali, miss pooja new song 2018, rabb vic...
# 5-Minute Crafts                                     (any, aromatic, clean hands, amazing, fruit, e...
# The Screen Patti                                    (aaj tak, walas, mystery, miyan, hindi news, k...
# ...                                                                                               ...
# Skylark Pictures Entertainment                      (fest, food, priya, eye, popular, ktu, whatsap...
# Jayaraj G Nath                                      (tutorial, whatsapp, whatsapp malayalam tricks...
# YouTube Got Talent                                  (Scariest Audition Ever, The sacred riana, cre...
# BeautyExperts                                       (à¤à¤¸à¥ à¤²à¤à¤¾à¤¤à¤¾à¤° 3 à¤¦à¤¿à¤¨ à¤à...
# Relique Records                                     (GAL NI KADNI, CUTE MUNDA, JEEEJU, KANIKA MANN...
# Tamil News World - à®¤à®®à®¿à®´à¯ à®à¯à®¯à¯...  (jayalalitha treatment video, jayalalitha vide...
# BapaoGiri                                           (skrillex copied, lovato, song, bapogiri, rip ...
# JackieMT 2nd                                        (Lionel Messi, Cristiano Ronaldo, Neymar, Serg...
# Reporter Roy                                        (Bengali Serial, Nayna Banerjee, Bengali Actre...
# BLUSH                                               (international women's day 2018, international...
# Reporter Tolpar                                     (bangladeshi news, salman, salman khan in jail...
# Smart Series                                        (dhaval domadiya, surat, tarun, fore, smartser...
# Filmi News                                          (big boss kannada, Kirik Keerthi Bigg Boss Kan...
# KCT News                                            (mohammad shami controversy, mohammad shami ca...
# Wide Angle Pictures                                 (latest, pictures, telugu, wide, popular, angl...
# Business Of Cinema                                  (businessofcinema, boc, aishwarya rai bachchan...
# We Are A Sambavam : The Malayalam Comedy Channel    (google home mini troll, funny video, weareasa...
# SS TV TAMIL                                         (tamil news, GoaTourist Spots, India Facts, Go...
# Jenny Farare                                        (àªàªàª°à« àª¶à«àª àª¥àª¯à«àª àª°àª¾àª...
# Boombox Music                                       (kings of media, latest punjabi song 2018, hig...
# BollywoodKilla                                      (Bigg Boss 11, Arshi Khan, Jyoti Kumari, Mehja...
# Top 5                                               (Jhanvi kapoor, Bollywood actress Sridevi, Khu...
# Mallika                                             (song, ghanti, rapper in india, omprakash mish...
# Malayalam Filmibeat                                 (à´¸à´¿à´¨à´¿à´®, à´¨à´à´¿, à´µà´¿à´µà´¾à´¹à´...
# WowShow                                             (trick, EXPERIMENT, awesome, life hacks, auto ...
# Bollywood Sins                                      (Anushka Shetty, #popularonyoutubeindia, Bahub...
# Wrestling Reality                                                                           ([none],)
# OCEAN MOVIE TALKIES                                 (full movie download mp4, Tiger Zinda Hai hind...
# STAR à¤­à¤¾à¤°à¤¤                                   (valentines, problem solver, à¤à¤¯ à¤à¤¨à¥à...
# Frogs Lehren                                        (SonyLIV, Archita Agarwal, web series by kabir...
#
#                                                     count
# channel_title
# VikatanTV                                             284
# etvteluguindia                                        282
# Flowers Comedy                                        270
# ETV Plus India                                        253
# SAB TV                                                244
# RadaanMedia                                           243
# mallemalatv                                           238
# SET India                                             238
# ETV Jabardasth                                        234
# Vijay Television                                      231
# Tarang TV                                             223
# T-Series                                              221
# Mazhavil Manorama                                     220
# Technical Guruji                                      215
# Study IQ education                                    213
# V6 News Telugu                                        212
# zeetv                                                 198
# Speed Records                                         197
# SunTV Tamil                                           196
# zeetvtelugu                                           193
# Black Sheep                                           192
# zeemarathi                                            191
# Colors TV                                             186
# FilterCopy                                            182
# Sony PAL                                              182
# Saregama TVShows                                      182
# Aditya Music                                          180
# T-Series Apna Punjab                                  179
# 5-Minute Crafts                                       173
# The Screen Patti                                      170
# ...                                                   ...
# Skylark Pictures Entertainment                          1
# Jayaraj G Nath                                          1
# YouTube Got Talent                                      1
# BeautyExperts                                           1
# Relique Records                                         1
# Tamil News World - à®¤à®®à®¿à®´à¯ à®à¯à®¯à¯...      1
# BapaoGiri                                               1
# JackieMT 2nd                                            1
# Reporter Roy                                            1
# BLUSH                                                   1
# Reporter Tolpar                                         1
# Smart Series                                            1
# Filmi News                                              1
# KCT News                                                1
# Wide Angle Pictures                                     1
# Business Of Cinema                                      1
# We Are A Sambavam : The Malayalam Comedy Channel        1
# SS TV TAMIL                                             1
# Jenny Farare                                            1
# Boombox Music                                           1
# BollywoodKilla                                          1
# Top 5                                                   1
# Mallika                                                 1
# Malayalam Filmibeat                                     1
# WowShow                                                 1
# Bollywood Sins                                          1
# Wrestling Reality                                       1
# OCEAN MOVIE TALKIES                                     1
# STAR à¤­à¤¾à¤°à¤¤                                       1
# Frogs Lehren                                            1
#
# [1426 rows x 2 columns]

# %%
# we'll use a Counter to get the top 10

from collections import Counter

gb_all = df.groupby('channel_title')[['tags']]

def unique_tags(x):
    # split by '|'
    res = x.apply(lambda x: x.split('|')) 
    # flatten in single list
    flat = [elem.strip('"') for row in res for elem in row]
    # return a set (so it keeps only unique elements)
    return Counter(flat).most_common(10)

(gb_all.agg([unique_tags, 'count'])
       .droplevel(level=0, axis='columns')
       .sort_values(by='count', ascending=False)
)
# Out:
#                                                                                           unique_tags  \
# channel_title
# VikatanTV                                           [(priyamanaval serial, 169), (piriyamanaval, 1...
# etvteluguindia                                      [(jabardasth, 271), (extra jabardasth, 264), (...
# Flowers Comedy                                      [(flowers tv, 268), (flower tv comedy, 265), (...
# ETV Plus India                                      [(etv Plus, 253), (etv comedy show, 253), (3 I...
# SAB TV                                              [(sab tv serials, 214), (sab tv channel, 212),...
# RadaanMedia                                         [(Vaani rani, 242), (rani, 242), (Radhika in f...
# mallemalatv                                         [(All Time Hit Comedy Shows, 228), (Comedy Vid...
# SET India                                           [(the kapil sharma show, 158), (kapil sharma, ...
# ETV Jabardasth                                      [(etv shows, 234), (eenadu television, 234), (...
# Vijay Television                                    [(Tamil TV, 228), (Vijay TV, 227), (Star Vijay...
# Tarang TV                                           [(tarang, 223), (tarang tv, 223), (tarang tv s...
# T-Series                                            [(new hindi songs, 96), (latest hindi songs, 9...
# Mazhavil Manorama                                   [(mazhavil, 73), (manorama, 73), (mazhavil man...
# Technical Guruji                                    [(Gaurav Chaudhary, 154), (technical guruji, 1...
# Study IQ education                                  [(upsc, 134), (current affairs, 132), (studyiq...
# V6 News Telugu                                      [(teenmaar news, 179), (v6 teenmaar news, 167)...
# zeetv                                               [(full episode, 191), (zee tv, 189), (hindi, 1...
# Speed Records                                       [(speed records, 196), (punjabi songs, 187), (...
# SunTV Tamil                                         [(SunTV, 195), (SunTvTamizh, 195), (Tamil Chan...
# zeetvtelugu                                         [(zee telugu, 182), (full episode, 182), (telu...
# Black Sheep                                         [(black sheep, 93), (blacksheep, 81), (smile s...
# zeemarathi                                          [(Zee marathi, 185), (full episode, 185), (mar...
# Colors TV                                           [(Colors TV, 186), (colorstv, 186), (hindi sho...
# FilterCopy                                          [(screenpatti, 142), (filter copy, 138), (filt...
# Sony PAL                                            [(comedy, 124), (indian superhero, 115), (Sony...
# Saregama TVShows                                    [(sun tv serials, 173), (SunTV Shows, 173), (s...
# Aditya Music                                        [(Allu Arjun, 40), (Anu Emmanuel, 38), (Naa Pe...
# T-Series Apna Punjab                                [(punjabi songs, 141), (latest punjabi songs, ...
# 5-Minute Crafts                                     [(5-Minute Crafts, 173), (DIY, 173), (Do it yo...
# The Screen Patti                                    [(rabish, 148), (the, 146), (patti, 140), (scr...
# ...                                                                                               ...
# Skylark Pictures Entertainment                      [(sahrdaya, 1), (tech, 1), (fest, 1), (college...
# Jayaraj G Nath                                      [(android, 1), (demo, 1), (how to, 1), (jayara...
# YouTube Got Talent                                  [(She Summoned Her Ghost Friend on The Stage, ...
# BeautyExperts                                       [(Dettol à¤¸à¥ 5 à¤®à¤¿à¤¨à¤ à¤®à¥à¤ à¤ªà¥...
# Relique Records                                     [(new punjabi songs 2017, 1), (LATEST PUNJABI ...
# Tamil News World - à®¤à®®à®¿à®´à¯ à®à¯à®¯à¯...  [(jayalalitha death video, 1), (jayalalitha tr...
# BapaoGiri                                           [(bapao, 1), (bapaogiri, 1), (copied, 1), (cop...
# JackieMT 2nd                                        [(Football Fights, 1), (Angry Moments, 1), (20...
# Reporter Roy                                        [(ReporterRoy, 1), (On, 1), (The, 1), (Rise, 1...
# BLUSH                                               [(Every women's day video ever, 1), (women's d...
# Reporter Tolpar                                     [(bangla news, 1), (bangladeshi news, 1), (ban...
# Smart Series                                        [(Jigli and Kharuj, 1), (Jigli, 1), (Khajur, 1...
# Filmi News                                          [(anupama gowda marriage, 1), (Kirik Keerthi B...
# KCT News                                            [(mohammad shami controversy, 1), (mohammed sh...
# Wide Angle Pictures                                 [(wide, 1), (angle, 1), (pictures, 1), (telugu...
# Business Of Cinema                                  [(businessofcinema, 1), (boc, 1), (bollywood, ...
# We Are A Sambavam : The Malayalam Comedy Channel    [(weareasambavam, 1), (comedy, 1), (malayalam ...
# SS TV TAMIL                                         [(tamil news, 1), (WorldCountry Facts, 1), (In...
# Jenny Farare                                        [(àªàªàª°à« àª¶à«àª àª¥àª¯à«àª àª°àª¾àª...
# Boombox Music                                       [(sarthi k, 1), (high nakhre, 1), (full video,...
# BollywoodKilla                                      [(BollywoodKilla, 1), (Bigg Boss 11, 1), (Mehj...
# Top 5                                               [(Sridevi, 1), (Sridevi prayer meet, 1), (Boll...
# Mallika                                             [(lyricist, 1), (aunty ki gunty rap, 1), (aunt...
# Malayalam Filmibeat                                 [(divya unni, 1), (actress, 1), (marriage, 1),...
# WowShow                                             [(EXPERIMENT, 1), (car, 1), (car vs car, 1), (...
# Bollywood Sins                                      [(Bahubali 2, 1), (Baahubali 2 The Conclusion,...
# Wrestling Reality                                                                       [([none], 1)]
# OCEAN MOVIE TALKIES                                 [(tiger zinda hai promotion video, 1), (watch ...
# STAR à¤­à¤¾à¤°à¤¤                                   [(à¤ªà¥à¤°à¥à¤®à¥, 1), (à¤¸à¥à¤à¤¾à¤° à¤­...
# Frogs Lehren                                        [(VirginWomanDiaries, 1), (Season Finale, 1), ...
#
#                                                     count
# channel_title
# VikatanTV                                             284
# etvteluguindia                                        282
# Flowers Comedy                                        270
# ETV Plus India                                        253
# SAB TV                                                244
# RadaanMedia                                           243
# mallemalatv                                           238
# SET India                                             238
# ETV Jabardasth                                        234
# Vijay Television                                      231
# Tarang TV                                             223
# T-Series                                              221
# Mazhavil Manorama                                     220
# Technical Guruji                                      215
# Study IQ education                                    213
# V6 News Telugu                                        212
# zeetv                                                 198
# Speed Records                                         197
# SunTV Tamil                                           196
# zeetvtelugu                                           193
# Black Sheep                                           192
# zeemarathi                                            191
# Colors TV                                             186
# FilterCopy                                            182
# Sony PAL                                              182
# Saregama TVShows                                      182
# Aditya Music                                          180
# T-Series Apna Punjab                                  179
# 5-Minute Crafts                                       173
# The Screen Patti                                      170
# ...                                                   ...
# Skylark Pictures Entertainment                          1
# Jayaraj G Nath                                          1
# YouTube Got Talent                                      1
# BeautyExperts                                           1
# Relique Records                                         1
# Tamil News World - à®¤à®®à®¿à®´à¯ à®à¯à®¯à¯...      1
# BapaoGiri                                               1
# JackieMT 2nd                                            1
# Reporter Roy                                            1
# BLUSH                                                   1
# Reporter Tolpar                                         1
# Smart Series                                            1
# Filmi News                                              1
# KCT News                                                1
# Wide Angle Pictures                                     1
# Business Of Cinema                                      1
# We Are A Sambavam : The Malayalam Comedy Channel        1
# SS TV TAMIL                                             1
# Jenny Farare                                            1
# Boombox Music                                           1
# BollywoodKilla                                          1
# Top 5                                                   1
# Mallika                                                 1
# Malayalam Filmibeat                                     1
# WowShow                                                 1
# Bollywood Sins                                          1
# Wrestling Reality                                       1
# OCEAN MOVIE TALKIES                                     1
# STAR à¤­à¤¾à¤°à¤¤                                       1
# Frogs Lehren                                            1
#
# [1426 rows x 2 columns]

# %% [markdown]
# ## 2. What are the top 25 tags in each country ?
#
# - Approach 1 [ok]: Get the data and reproduce our logic
# - Approach 2 [better]: We use a
# - Approach 3 [best]: We reuse our unique_tags function

# %%
# 1. Redo the logic
all_tags = df['tags'].apply(lambda x: x.split('|')).values
all_tags = [elem.strip('"') for row in all_tags for elem in row]
top25 = Counter(all_tags).most_common(25)
top25
# Out:
# [('comedy', 2384),
#  ('funny', 2129),
#  ('television', 1414),
#  ('show', 1400),
#  ('[none]', 1381),
#  ('serial', 1330),
#  ('full episode', 1303),
#  ('funny videos', 1249),
#  ('daily soap', 1235),
#  ('watch online', 1229),
#  ('latest news', 994),
#  ('2018', 958),
#  ('news', 919),
#  ('jabardasth', 898),
#  ('India', 836),
#  ('bollywood', 820),
#  ('entertainment', 806),
#  ('telugu', 805),
#  ('punjabi songs', 786),
#  ('extra jabardasth', 783),
#  ('latest', 772),
#  ('india', 772),
#  ('Zee5', 766),
#  ('hindi', 765),
#  ('breaking news', 697)]

# %%
# 2. Groupby obsession
# hackish, but works
def unique_tags(x, top: int=10):
    # split by '|'
    res = x.apply(lambda x: x.split('|')) 
    # flatten in single list
    flat = [elem.strip('"') for row in res for elem in row]
    # return a set (so it keeps only unique elements)
    return Counter(flat).most_common(top)

df['all'] = 1
df.groupby('all')[['tags']].agg(unique_tags, top=25)['tags'].values[0]
# Out:
# [('comedy', 2384),
#  ('funny', 2129),
#  ('television', 1414),
#  ('show', 1400),
#  ('[none]', 1381),
#  ('serial', 1330),
#  ('full episode', 1303),
#  ('funny videos', 1249),
#  ('daily soap', 1235),
#  ('watch online', 1229),
#  ('latest news', 994),
#  ('2018', 958),
#  ('news', 919),
#  ('jabardasth', 898),
#  ('India', 836),
#  ('bollywood', 820),
#  ('entertainment', 806),
#  ('telugu', 805),
#  ('punjabi songs', 786),
#  ('extra jabardasth', 783),
#  ('latest', 772),
#  ('india', 772),
#  ('Zee5', 766),
#  ('hindi', 765),
#  ('breaking news', 697)]

# %%
# 3. or simply this
unique_tags(df['tags'], top=25)
# Out:
# [('comedy', 2384),
#  ('funny', 2129),
#  ('television', 1414),
#  ('show', 1400),
#  ('[none]', 1381),
#  ('serial', 1330),
#  ('full episode', 1303),
#  ('funny videos', 1249),
#  ('daily soap', 1235),
#  ('watch online', 1229),
#  ('latest news', 994),
#  ('2018', 958),
#  ('news', 919),
#  ('jabardasth', 898),
#  ('India', 836),
#  ('bollywood', 820),
#  ('entertainment', 806),
#  ('telugu', 805),
#  ('punjabi songs', 786),
#  ('extra jabardasth', 783),
#  ('latest', 772),
#  ('india', 772),
#  ('Zee5', 766),
#  ('hindi', 765),
#  ('breaking news', 697)]

# %% [markdown]
# ## Fix the bugs
#
# - Remove the ugly [none]
# - fix the casing
